# %%
import json
import pandas as pd
import numpy as np
import datetime
import re
import matplotlib.pyplot as plt
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
source='new 2.json'

# %%
fvt_count=[]
ret_count=[]
texts=[]
date_creation=[]
cmp_scr=[]
sources=[]
with open(source, encoding='UTF-8') as datafile:
    sample_data=json.load(datafile)
    for tweet in sample_data:
        date=tweet['created_at']
        text=tweet['text']
        source=tweet['source']
        fvt=tweet['favorite_count']
        ret=tweet['retweet_count']
        
        results = analyzer.polarity_scores(text)
        compound = results["compound"]
        
      
        
        fvt_count.append(fvt)
        ret_count.append(ret)
        texts.append(text)
        cmp_scr.append(compound)
        date_creation.append(date)
        sources.append(source)

# %%
print(len(texts))
# Out:
# 33354

# %%
Trump_df=pd.DataFrame({'Date':date_creation,'Tweet':texts,'Compound Score':cmp_scr,'Favorite Counts':fvt_count,
                      'Retweet Counts':ret_count,'Tweet Source':sources})
Trump_df.head()
# Out:
#    Compound Score                            Date  Favorite Counts  \
# 0          0.9577  Tue Apr 10 18:30:38 +0000 2018            37017
# 1          0.9577  Tue Apr 10 17:51:08 +0000 2018            24427
# 2          0.9340  Tue Apr 10 13:30:35 +0000 2018            53867
# 3         -0.5229  Tue Apr 10 11:08:18 +0000 2018            92881
# 4         -0.4753  Tue Apr 10 11:07:58 +0000 2018            81975
#
#    Retweet Counts                                              Tweet  \
# 0            8036  Very thankful for President Xi of China’s kind...
# 1            5869  Very thankful for President Xi of China’s kind...
# 2           12395  Last night, it was my great honor to host Amer...
# 3           24409                              A TOTAL WITCH HUNT!!!
# 4           22029                 Attorney–client privilege is dead!
#
#          Tweet Source
# 0  Twitter for iPhone
# 1  Twitter for iPhone
# 2  Twitter for iPhone
# 3  Twitter for iPhone
# 4  Twitter for iPhone

# %%
for date in Trump_df['Date']:
    dt=datetime.datetime.strptime(date, "%a %b %d %H:%M:%S %z %Y")

# %%
daily_dt=pd.to_datetime(Trump_df['Date']).dt.to_period('d')
monthly_dt=pd.to_datetime(Trump_df['Date']).dt.to_period('m')
yearly_dt=pd.to_datetime(Trump_df['Date']).dt.to_period('y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     623             split = name.split('-')
# --> 624             klass = prefix_mapping[split[0]]
#     625             # handles case where there's no suffix (and will TypeError if too
#
# KeyError: 'Y'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     549                 stride = int(stride)
# --> 550                 offset = get_offset(name)
#     551                 offset = offset * int(np.fabs(stride) * stride_sign)
#
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     629             # bad prefix or suffix
# --> 630             raise ValueError(_INVALID_FREQ_ERROR.format(name))
#     631         # cache
#
# ValueError: Invalid frequency: Y
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c54c74788e2e> in <module>()
#       1 daily_dt=pd.to_datetime(Trump_df['Date']).dt.to_period('d')
#       2 monthly_dt=pd.to_datetime(Trump_df['Date']).dt.to_period('m')
# ----> 3 yearly_dt=pd.to_datetime(Trump_df['Date']).dt.to_period('y')
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in f(self, *args, **kwargs)
#     209
#     210             def f(self, *args, **kwargs):
# --> 211                 return self._delegate_method(name, *args, **kwargs)
#     212
#     213             f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in _delegate_method(self, name, *args, **kwargs)
#     131
#     132         method = getattr(self.values, name)
# --> 133         result = method(*args, **kwargs)
#     134
#     135         if not is_list_like(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in to_period(self, freq)
#     942             freq = get_period_alias(freq)
#     943
# --> 944         return PeriodIndex(self.values, name=self.name, freq=freq, tz=self.tz)
#     945
#     946     def snap(self, freq='S'):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\period.py in __new__(cls, data, ordinal, freq, start, end, periods, copy, name, tz, dtype, **kwargs)
#     227         # which is slow
#     228         if freq:
# --> 229             freq = Period._maybe_convert_freq(freq)
#     230
#     231         if data is None:
#
# pandas/_libs/period.pyx in pandas._libs.period._Period._maybe_convert_freq (pandas\_libs\period.c:11195)()
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     555                     delta = delta + offset
#     556         except Exception:
# --> 557             raise ValueError(_INVALID_FREQ_ERROR.format(freq))
#     558
#     559     if delta is None:
#
# ValueError: Invalid frequency: y

# %%
Trump_df["Daily Date"]=daily_dt
Trump_df["Monthly Date"]=monthly_dt
Trump_df["Yearly Date"]=yearly_dt
# Out:
#        Compound Score                            Date  Favorite Counts  \
# 0              0.9577  Tue Apr 10 18:30:38 +0000 2018            37017
# 1              0.9577  Tue Apr 10 17:51:08 +0000 2018            24427
# 2              0.9340  Tue Apr 10 13:30:35 +0000 2018            53867
# 3             -0.5229  Tue Apr 10 11:08:18 +0000 2018            92881
# 4             -0.4753  Tue Apr 10 11:07:58 +0000 2018            81975
# 5              0.6588  Mon Apr 09 19:32:27 +0000 2018            45438
# 6              0.6588  Mon Apr 09 19:17:39 +0000 2018            91057
# 7             -0.8720  Mon Apr 09 16:55:41 +0000 2018                0
# 8              0.8465  Mon Apr 09 10:03:16 +0000 2018           165207
# 9              0.9899  Mon Apr 09 00:43:27 +0000 2018            87800
# 10            -0.6892  Sun Apr 08 13:12:57 +0000 2018            86736
# 11            -0.8528  Sun Apr 08 13:04:22 +0000 2018            64037
# 12            -0.8360  Sun Apr 08 13:00:06 +0000 2018            97399
# 13             0.7901  Sun Apr 08 12:12:35 +0000 2018           102903
# 14             0.8775  Sun Apr 08 11:58:13 +0000 2018            77182
# 15             0.8066  Sun Apr 08 11:44:23 +0000 2018             2174
# 16             0.6077  Sun Apr 08 11:27:49 +0000 2018            74547
# 17             0.8087  Sun Apr 08 00:03:23 +0000 2018            73066
# 18             0.7371  Sat Apr 07 22:42:22 +0000 2018           133125
# 19             0.8117  Sat Apr 07 21:00:39 +0000 2018            90979
# 20            -0.9006  Sat Apr 07 20:52:58 +0000 2018            76617
# 21             0.7836  Sat Apr 07 18:11:15 +0000 2018           104789
# 22            -0.6996  Sat Apr 07 18:03:56 +0000 2018            87746
# 23            -0.6114  Sat Apr 07 17:35:28 +0000 2018            90939
# 24             0.9381  Fri Apr 06 20:26:53 +0000 2018            39348
# 25             0.0000  Fri Apr 06 20:23:58 +0000 2018            94457
# 26             0.0000  Fri Apr 06 16:24:27 +0000 2018            66923
# 27            -0.7508  Fri Apr 06 14:46:10 +0000 2018            89236
# ...                    ...        ...          ...         ...
# 23352  Twitter for Android 2013-08-02      2013-08        2013
# 31922      TwitLonger Beta 2012-03-15      2012-03        2012
# 22241  Twitter for Android 2013-09-17      2013-09        2013
# 25749  Twitter for Android 2013-04-24      2013-04        2013
# 884     Twitter for iPhone 2017-11-15      2017-11        2017
# 705     Twitter for iPhone 2017-12-08      2017-12        2017
# 6294   Twitter for Android 2016-03-07      2016-03        2016
# 4988   Twitter for Android 2016-07-04      2016-07        2016
# 7897   Twitter for Android 2015-12-04      2015-12        2015
# 5410   Twitter for Android 2016-05-22      2016-05        2016
# 2057    Twitter for iPhone 2017-07-10      2017-07        2017
# 9266   Twitter for Android 2015-10-04      2015-10        2015
# 32684            TweetDeck 2011-10-27      2011-10        2011
# 3188   Twitter for Android 2016-12-23      2016-12        2016
# 4808   Twitter for Android 2016-07-23      2016-07        2016
# 17577  Twitter for Android 2014-08-02      2014-08        2014
# 744     Twitter for iPhone 2017-12-03      2017-12        2017
# 11449  Twitter for Android 2015-05-31      2015-05        2015
# 11411   Twitter Web Client 2015-06-01      2015-06        2015
# 2921   Twitter for Android 2017-02-04      2017-02        2017
# 17554  Twitter for Android 2014-08-04      2014-08        2014
# 33      Twitter for iPhone 2018-04-05      2018-04        2018
# 110     Twitter for iPhone 2018-03-22      2018-03        2018
# 3320   Twitter for Android 2016-11-29      2016-11        2016
# 12127  Twitter for Android 2015-05-01      2015-05        2015
# 20284   Twitter Web Client 2014-02-13      2014-02        2014
# 26994   Twitter Web Client 2013-03-11      2013-03        2013
# 20789  Twitter for Android 2013-12-22      2013-12        2013
# 23909  Twitter for Android 2013-07-13      2013-07        2013
# 5198   Twitter for Android 2016-06-12      2016-06        2016
#
# [100 rows x 9 columns]

# %%
Daily_avg=Trump_df.groupby('Daily Date')['Compound Score'].mean()
Daily_dataframe=pd.DataFrame({'Daily Comp Score':Daily_avg})
Daily_dataframe.plot(kind='line',y='Daily Comp Score' ,linestyle='None', marker='o',figsize=(10,10))

# %%
Monthly_avg=Trump_df.groupby('Monthly Date')['Compound Score'].mean()
Monthly_dataframe=pd.DataFrame({'Monthly Comp Score':Monthly_avg})
Monthly_dataframe.plot(kind='line',y='Monthly Comp Score' ,linestyle='None', marker='o',figsize=(10,10))

# %%
# Create bins in which to place values based upon TED Talk views
bins = [-1.0,-0.5,0,0.5,1.0]

# Create labels for these bins
group_labels = ["Really Pessimistic","Mildy mad","having a nice day",
                "totally chilled"]
group= ['-1.0 to -0.5','-0.5 to 0.0','0.0 to 0.5','0.5 to 1.0']

# %%
Daily_dataframe['Comp Group']= pd.cut(Daily_dataframe["Daily Comp Score"],bins,labels=group)
d=Daily_dataframe.groupby('Comp Group').count()
d
# Out:
#               Daily Comp Score
# Comp Group
# -1.0 to -0.5                17
# -0.5 to 0.0                479
# 0.0 to 0.5                1661
# 0.5 to 1.0                 336

# %%
d.plot(kind='pie',y='Daily Comp Score', legend=None, autopct= '%1.1f%%', figsize=(6,6))
plt.axis('equal')
plt.ylabel('')
plt.show()
